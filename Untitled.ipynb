# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import seaborn as sns
import pickle
sns.set_theme()

# %%
dataset = pd.read_csv("iris.csv")
print(dataset.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.relplot(data=dataset,x="SepalWidthCm",y="PetalLengthCm",hue="Species")

# %%
x = dataset.drop(["Species","Id"],axis=True)
y = dataset["Species"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=25)

classifier = KNeighborsClassifier()
classifier.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = dataset.drop(["Species","id"],axis=True)
#       2 y = dataset["Species"]
#       3 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=25)
#
# File ~/.cache/pypoetry/virtualenvs/ml-website-YHF0hz0e-py3.8/lib/python3.8/site-packages/pandas/core/frame.py:5266, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5118 def drop(
#    5119     self,
#    5120     labels: IndexLabel = None,
#    (...)
#    5127     errors: IgnoreRaise = "raise",
#    5128 ) -> DataFrame | None:
#    5129     """
#    5130     Drop specified labels from rows or columns.
#    5131
#    (...)
#    5264             weight  1.0     0.8
#    5265     """
# -> 5266     return super().drop(
#    5267         labels=labels,
#    5268         axis=axis,
#    5269         index=index,
#    5270         columns=columns,
#    5271         level=level,
#    5272         inplace=inplace,
#    5273         errors=errors,
#    5274     )
#
# File ~/.cache/pypoetry/virtualenvs/ml-website-YHF0hz0e-py3.8/lib/python3.8/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/.cache/pypoetry/virtualenvs/ml-website-YHF0hz0e-py3.8/lib/python3.8/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/.cache/pypoetry/virtualenvs/ml-website-YHF0hz0e-py3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['id'] not found in axis"

# %%
y_pred = classifier.predict(x_test)
accuracy_score(y_test,y_pred)

# %%
filename = "model.pkl"
pickle.dump(classifier, open(filename, "wb"))
